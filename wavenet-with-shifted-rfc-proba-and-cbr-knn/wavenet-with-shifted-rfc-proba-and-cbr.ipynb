# %% [markdown]
# # Thanks to https://www.kaggle.com/siavrez/wavenet-keras and Sergey Bryansky.
# # You can take a look at Sergey's kernel [here](https://www.kaggle.com/sggpls/shifted-rfc-pipeline) or [here](https://www.kaggle.com/sggpls/wavenet-with-shifted-rfc-proba). Also, Sergey's [data is here.](https://www.kaggle.com/sggpls/ion-shifted-rfc-proba)

# %%
# !pip install tensorflow_addons
import tensorflow as tf
from tensorflow.keras.layers import *
import pandas as pd
import numpy as np
import random
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
import tensorflow_addons as tfa
import gc

from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.7/site-packages (from tensorflow_addons) (2.7.1)

# %%
# configurations and main hyperparammeters
EPOCHS = 180
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 321
LR = 0.001
SPLITS = 5

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %%
# import matplotlib.pyplot as plt

# a = np.load("../input/knn-oof/oof_knn_feats.npy")
# b = np.load("../input/ion-shifted-rfc-proba/Y_train_proba.npy")

# for i in np.random.randint(0, 2000000, size=10):
#     print(plt.plot(a[i, 11:22]))
#     print(plt.plot(b[i]))
#     plt.show()

# %%
# read data
def read_data():
    train = pd.read_csv('../input/data-without-drift/train_clean.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv('../input/data-without-drift/test_clean.csv', dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv('../input/liverpool-ion-switching/sample_submission.csv', dtype={'time': np.float32})
    
    Y_train_proba = np.load("../input/ion-shifted-rfc-proba/Y_train_proba.npy")
    Y_test_proba = np.load("../input/ion-shifted-rfc-proba/Y_test_proba.npy")
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]
        
    train_knn_feats = np.load("../input/knn-oof/oof_knn_feats.npy")
    test_knn_feats = np.load("../input/knn-oof/test_knn_feats.npy")
    
    for i in range(11, 22):
        train[f"knn_feat_{i}"] = train_knn_feats[:, i]
        test[f"knn_feat_{i}"] = test_knn_feats[:, i]

    return train, test, sub

# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    train_input_mean = train.signal.mean()
    train_input_sigma = train.signal.std()
    train['signal'] = (train.signal - train_input_mean) / train_input_sigma
    test['signal'] = (test.signal - train_input_mean) / train_input_sigma
    return train, test

# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)
    # create leads and lags (1, 2, 3 making them 6 features)
    df = lag_with_pct_change(df, [1, 2, 3])
    # create signal ** 2 (this is the new feature)
    df['signal_2'] = df['signal'] ** 2
    return df

# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# model function (very important, you can try different arquitectures to get a better score. I believe that top public leaderboard is a 1D Conv + RNN style)
def Classifier(shape_):
    
    def cbr(x, out_layer, kernel, stride, dilation):
        x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        return x
    
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters = filters,
                   kernel_size = 1,
                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = Multiply()([tanh_out, sigm_out])
            x = Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = Add()([res_x, x])
        return res_x
    
    inp = Input(shape = (shape_))
    x = cbr(inp, 64, 7, 1, 1)
    x = BatchNormalization()(x)
    x = wave_block(x, 16, 3, 12)
    x = BatchNormalization()(x)
    x = wave_block(x, 32, 3, 8)
    x = BatchNormalization()(x)
    x = wave_block(x, 64, 3, 4)
    x = BatchNormalization()(x)
    x = wave_block(x, 128, 3, 1)
    x = cbr(x, 32, 7, 1, 1)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    out = Dense(11, activation = 'softmax', name = 'out')(x)
    
    model = models.Model(inputs = inp, outputs = out)
    
    opt = Adam(lr = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    return model

# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    else:
        lr = LR / 100
    return lr

# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')

# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
    config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
    tf.compat.v1.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))
    
    print(train.shape)

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')

        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        model = Classifier(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 2,
                  validation_data = (valid_x,valid_y))
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv('submission_wavenet.csv', index=False, float_format='%.4f')
    
# this function run our entire program
def run_everything():
    
    print('Reading Data Started...')
    train, test, sample_submission = read_data()
    train, test = normalize(train, test)
    print('Reading and Normalizing Data Completed')
        
    print('Creating Features')
    print('Feature Engineering Started...')
    train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
    test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)
    train, test, features = feature_selection(train, test)
    print('Feature Engineering Completed...')
        
   
    print(f'Training Wavenet model with {SPLITS} folds of GroupKFold Started...')
    run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
    print('Training completed...')
        
run_everything()
# Out:
# Reading Data Started...
# Reading and Normalizing Data Completed
# Creating Features
# Feature Engineering Started...
# Feature Engineering Completed...
# Training Wavenet model with 5 folds of GroupKFold Started...
# (1250, 4000, 30)
# Our training dataset shape is (1000, 4000, 30)
# Our validation dataset shape is (250, 4000, 30)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# F1 Macro Score: 0.78607
# 1000/1000 - 44s - loss: 0.5428 - accuracy: 0.8551 - val_loss: 0.8188 - val_accuracy: 0.9230
# Epoch 2/180
# F1 Macro Score: 0.85229
# 1000/1000 - 10s - loss: 0.1919 - accuracy: 0.9575 - val_loss: 0.4524 - val_accuracy: 0.9541
# Epoch 3/180
# F1 Macro Score: 0.93007
# 1000/1000 - 10s - loss: 0.1501 - accuracy: 0.9636 - val_loss: 0.2432 - val_accuracy: 0.9636
# Epoch 4/180
# F1 Macro Score: 0.93574
# 1000/1000 - 10s - loss: 0.1365 - accuracy: 0.9649 - val_loss: 0.1514 - val_accuracy: 0.9651
# Epoch 5/180
# F1 Macro Score: 0.93532
# 1000/1000 - 10s - loss: 0.1273 - accuracy: 0.9656 - val_loss: 0.1259 - val_accuracy: 0.9654
# Epoch 6/180
# F1 Macro Score: 0.93680
# 1000/1000 - 10s - loss: 0.1269 - accuracy: 0.9654 - val_loss: 0.1119 - val_accuracy: 0.9658
# Epoch 7/180
# F1 Macro Score: 0.93725
# F1 Macro Score: 0.93705
# 1000/1000 - 10s - loss: 0.0975 - accuracy: 0.9670 - val_loss: 0.0927 - val_accuracy: 0.9664
# Epoch 26/180
# F1 Macro Score: 0.93799
# 1000/1000 - 10s - loss: 0.0955 - accuracy: 0.9674 - val_loss: 0.0915 - val_accuracy: 0.9668
# Epoch 27/180
# F1 Macro Score: 0.93743
# 1000/1000 - 10s - loss: 0.0932 - accuracy: 0.9677 - val_loss: 0.0909 - val_accuracy: 0.9666
# Epoch 28/180
# F1 Macro Score: 0.93645
# 1000/1000 - 10s - loss: 0.0921 - accuracy: 0.9679 - val_loss: 0.0923 - val_accuracy: 0.9663
# Epoch 29/180
# F1 Macro Score: 0.93782
# 1000/1000 - 9s - loss: 0.0932 - accuracy: 0.9676 - val_loss: 0.0913 - val_accuracy: 0.9668
# Epoch 30/180
# F1 Macro Score: 0.93610
# 1000/1000 - 9s - loss: 0.0928 - accuracy: 0.9678 - val_loss: 0.0940 - val_accuracy: 0.9658
# Epoch 31/180
# F1 Macro Score: 0.93850
# 1000/1000 - 9s - loss: 0.0897 - accuracy: 0.9684 - val_loss: 0.0878 - val_accuracy: 0.9673
# Epoch 32/180
# F1 Macro Score: 0.93915
# 1000/1000 - 9s - loss: 0.0886 - accuracy: 0.9686 - val_loss: 0.0873 - val_accuracy: 0.9676
# Epoch 33/180
# F1 Macro Score: 0.93934
# 1000/1000 - 10s - loss: 0.0885 - accuracy: 0.9686 - val_loss: 0.0868 - val_accuracy: 0.9675
# Epoch 34/180
# F1 Macro Score: 0.93920
# 1000/1000 - 9s - loss: 0.0874 - accuracy: 0.9689 - val_loss: 0.0862 - val_accuracy: 0.9677
# Epoch 35/180
# F1 Macro Score: 0.94028
# 1000/1000 - 10s - loss: 0.0873 - accuracy: 0.9689 - val_loss: 0.0853 - val_accuracy: 0.9680
# Epoch 36/180
# F1 Macro Score: 0.93990
# 1000/1000 - 9s - loss: 0.0868 - accuracy: 0.9690 - val_loss: 0.0853 - val_accuracy: 0.9679
# Epoch 37/180
# F1 Macro Score: 0.93986
# 1000/1000 - 9s - loss: 0.0878 - accuracy: 0.9688 - val_loss: 0.0859 - val_accuracy: 0.9679
# Epoch 38/180
# F1 Macro Score: 0.94002
# 1000/1000 - 9s - loss: 0.0874 - accuracy: 0.9689 - val_loss: 0.0855 - val_accuracy: 0.9680
# Epoch 39/180
# F1 Macro Score: 0.93873
# 1000/1000 - 9s - loss: 0.0862 - accuracy: 0.9692 - val_loss: 0.0876 - val_accuracy: 0.9674
# Epoch 40/180
# F1 Macro Score: 0.93987
# 1000/1000 - 9s - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.0851 - val_accuracy: 0.9681
# Epoch 41/180
# F1 Macro Score: 0.93956
# 1000/1000 - 9s - loss: 0.0852 - accuracy: 0.9694 - val_loss: 0.0857 - val_accuracy: 0.9680
# Epoch 42/180
# F1 Macro Score: 0.94069
# 1000/1000 - 9s - loss: 0.0855 - accuracy: 0.

# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.71372
# 1000/1000 - 35s - loss: 0.6057 - accuracy: 0.8336 - val_loss: 0.8143 - val_accuracy: 0.8994
# Epoch 2/180
# F1 Macro Score: 0.88180
# 1000/1000 - 9s - loss: 0.2180 - accuracy: 0.9528 - val_loss: 0.4548 - val_accuracy: 0.9587
# Epoch 3/180
# F1 Macro Score: 0.92357
# 1000/1000 - 9s - loss: 0.1587 - accuracy: 0.9625 - val_loss: 0.2445 - val_accuracy: 0.9661
# Epoch 4/180
# F1 Macro Score: 0.93654
# 1000/1000 - 10s - loss: 0.1412 - accuracy: 0.9642 - val_loss: 0.1482 - val_accuracy: 0.9682
# Epoch 5/180
# F1 Macro Score: 0.93692
# 1000/1000 - 9s - loss: 0.1314 - accuracy: 0.9650 - val_loss: 0.1172 - val_accuracy: 0.9685
# Epoch 6/180
# F1 Macro Score: 0.93892
# 1000/1000 - 9s - loss: 0.1269 - accuracy: 0.9652 - val_loss: 0.1071 - val_accuracy: 0.9690
# Epoch 7/180
# F1 Macro Score: 0.93731
# 1000/1000 - 9s - loss: 0.1234 - accuracy: 0.9653 - val_loss: 0.1151 - val_accuracy: 0.9678
# Epoch 8/180
# F1 Macro Score: 0.93807
# 1000/1000 - 9s - loss: 0.1191 - accuracy: 0.9655 - val_loss: 0.0978 - val_accuracy: 0.9689
# Epoch 9/180
# F1 Macro Score: 0.93899
# 1000/1000 - 10s - loss: 0.1148 - accuracy: 0.9658 - val_loss: 0.0964 - val_accuracy: 0.9692
# Epoch 10/180
# F1 Macro Score: 0.93831
# 1000/1000 - 9s - loss: 0.1183 - accuracy: 0.9652 - val_loss: 0.0969 - val_accuracy: 0.9689
# Epoch 11/180
# F1 Macro Score: 0.93914
# 1000/1000 - 9s - loss: 0.1116 - accuracy: 0.9659 - val_loss: 0.0917 - val_accuracy: 0.9692
# Epoch 12/180
# F1 Macro Score: 0.93925
# 1000/1000 - 10s - loss: 0.1087 - accuracy: 0.9660 - val_loss: 0.0919 - val_accuracy: 0.9693
# Epoch 13/180
# F1 Macro Score: 0.93844
# 1000/1000 - 9s - loss: 0.1089 - accuracy: 0.9659 - val_loss: 0.0899 - val_accuracy: 0.9691
# Epoch 14/180
# F1 Macro Score: 0.93871
# 1000/1000 - 9s - loss: 0.1065 - accuracy: 0.9660 - val_loss: 0.0902 - val_accuracy: 0.9692
# Epoch 15/180
# F1 Macro Score: 0.93918
# 1000/1000 - 9s - loss: 0.1073 - accuracy: 0.9659 - val_loss: 0.0899 - val_accuracy: 0.9693
# Epoch 16/180
# F1 Macro Score: 0.93911
# 1000/1000 - 9s - loss: 0.1036 - accuracy: 0.9662 - val_loss: 0.0875 - val_accuracy: 0.9694
# Epoch 17/180
# F1 Macro Score: 0.93876
# 1000/1000 - 9s - loss: 0.1026 - accuracy: 0.9662 - val_loss: 0.0877 - val_accuracy: 0.9693
# Epoch 18/180
# F1 Macro Score: 0.93922
# F1 Macro Score: 0.93863
# 1000/1000 - 9s - loss: 0.0906 - accuracy: 0.9673 - val_loss: 0.0821 - val_accuracy: 0.9696
# Epoch 37/180
# F1 Macro Score: 0.93950
# 1000/1000 - 10s - loss: 0.0904 - accuracy: 0.9674 - val_loss: 0.0817 - val_accuracy: 0.9697
# Epoch 38/180
# F1 Macro Score: 0.93983
# 1000/1000 - 9s - loss: 0.0913 - accuracy: 0.9673 - val_loss: 0.0814 - val_accuracy: 0.9699
# Epoch 39/180
# F1 Macro Score: 0.93908
# 1000/1000 - 9s - loss: 0.0901 - accuracy: 0.9675 - val_loss: 0.0815 - val_accuracy: 0.9698
# Epoch 40/180
# F1 Macro Score: 0.93963
# 1000/1000 - 10s - loss: 0.0899 - accuracy: 0.9675 - val_loss: 0.0812 - val_accuracy: 0.9698
# Epoch 41/180
# F1 Macro Score: 0.94010
# 1000/1000 - 9s - loss: 0.0890 - accuracy: 0.9677 - val_loss: 0.0808 - val_accuracy: 0.9700
# Epoch 42/180
# F1 Macro Score: 0.93981
# 1000/1000 - 10s - loss: 0.0888 - accuracy: 0.9677 - val_loss: 0.0805 - val_accuracy: 0.9700
# Epoch 43/180
# F1 Macro Score: 0.93942
# 1000/1000 - 9s - loss: 0.0892 - accuracy: 0.9677 - val_loss: 0.0814 - val_accuracy: 0.9697
# Epoch 44/180
# F1 Macro Score: 0.94049
# 1000/1000 - 9s - loss: 0.0881 - accuracy: 0.9679 - val_loss: 0.0802 - val_accuracy: 0.9702
# Epoch 45/180
# F1 Macro Score: 0.93991
# 1000/1000 - 10s - loss: 0.0889 - accuracy: 0.9678 - val_loss: 0.0803 - val_accuracy: 0.9701
# Epoch 46/180
# F1 Macro Score: 0.94010
# 1000/1000 - 9s - loss: 0.0885 - accuracy: 0.9679 - val_loss: 0.0800 - val_accuracy: 0.9702
# Epoch 47/180
# F1 Macro Score: 0.93951
# 1000/1000 - 10s - loss: 0.0885 - accuracy: 0.9679 - val_loss: 0.0811 - val_accuracy: 0.9699
# Epoch 48/180
# F1 Macro Score: 0.94064
# 1000/1000 - 9s - loss: 0.0885 - accuracy: 0.9678 - val_loss: 0.0801 - val_accuracy: 0.9703
# Epoch 49/180
# F1 Macro Score: 0.94081
# 1000/1000 - 9s - loss: 0.0881 - accuracy: 0.9679 - val_loss: 0.0797 - val_accuracy: 0.9704
# Epoch 50/180
# F1 Macro Score: 0.94084
# 1000/1000 - 9s - loss: 0.0875 - accuracy: 0.9681 - val_loss: 0.0793 - val_accuracy: 0.9705
# Epoch 51/180
# F1 Macro Score: 0.94070
# 1000/1000 - 10s - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.0796 - val_accuracy: 0.9703
# Epoch 52/180
# F1 Macro Score: 0.94094
# 1000/1000 - 9s - loss: 0.0866 - accuracy: 0.9682 - val_loss: 0.0792 - val_accuracy: 0.9705
# Epoch 53/180
# F1 Macro Score: 0.94009
# 1000/1000 - 9s - loss: 0.0868 - accuracy: 0.9683 - val_loss: 0.0796 - val_accuracy: 0.9703
# Epoch 54/180
# F1 Macro Score: 0.94077
# 1000/1000 - 9s - loss: 0.0870 - accuracy: 0.9682 - val_loss: 0.0793 - val_accuracy: 0.9705
# Epoch 55/180
# F1 Macro Score: 0.94035
# 1000/1000 - 10s - loss: 0.0874 - accuracy: 0.9681 - val_loss: 0.0800 - val_accuracy: 0.9703
# Epoch 56/180
# F1 Macro Score: 0.94093
# 1000/1000 - 9s - loss: 0.0869 - accuracy: 0.9681 - val_loss: 0.0791 - val_accuracy: 0.9705
# Epoch 57/180
# F1 Macro Score: 0.94035
# 1000/1000 - 9s - loss: 0.0859 - accuracy: 0.9684 - val_loss: 0.0793 - val_accuracy: 0.9704
# Epoch 58/180
# F1 Macro Score: 0.94053
# 1000/1000 - 9s - loss: 0.0857 - accuracy: 0.9684 - val_loss: 0.0795 - val_accuracy: 0.9703
# Epoch 59/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0867 - accuracy: 0.9683 - val_loss: 0.0793 - val_accuracy: 0.9704
# Epoch 60/180
# F1 Macro Score: 0.94017
# 1000/1000 - 10s - loss: 0.0868 - accuracy: 0.9684 - val_loss: 0.0800 - val_accuracy: 0.9702
# Epoch 61/180
# F1 Macro Score: 0.94067
# 1000/1000 - 9s - loss: 0.0861 - accuracy: 0.9684 - val_loss: 0.0791 - val_accuracy: 0.9705
# Epoch 62/180
# F1 Macro Score: 0.94101
# 1000/1000 - 10s - loss: 0.0861 - accuracy: 0.9684 - val_loss: 0.0789 - val_accuracy: 0.9705
# Epoch 63/180
# F1 Macro Score: 0.94046
# 1000/1000 - 9s - loss: 0.0855 - accuracy: 0.9686 - val_loss: 0.0791 - val_accuracy: 0.9704
# Epoch 64/180
# F1 Macro Score: 0.94089
# 1000/1000 - 9s - loss: 0.0859 - accuracy: 0.9684 - val_loss: 0.0791 - val_accuracy: 0.9705
# Epoch 65/180
# F1 Macro Score: 0.94095
# 1000/1000 - 9s - loss: 0.0854 - accuracy: 0.9686 - val_loss: 0.0790 - val_accuracy: 0.9705
# Epoch 66/180
# F1 Macro Score: 0.94105
# 1000/1000 - 9s - loss: 0.0855 - accuracy: 0.9686 - val_loss: 0.0790 - val_accuracy: 0.9706
# Epoch 67/180
# F1 Macro Score: 0.94107
# 1000/1000 - 9s - loss: 0.0853 - accuracy: 0.9686 - val_loss: 0.0785 - val_accuracy: 0.9706
# Epoch 68/180
# F1 Macro Score: 0.94091
# 1000/1000 - 9s - loss: 0.0851 - accuracy: 0.9686 - val_loss: 0.0789 - val_accuracy: 0.9705
# Epoch 69/180
# F1 Macro Score: 0.94085
# 1000/1000 - 10s - loss: 0.0854 - accuracy: 0.9686 - val_loss: 0.0789 - val_accuracy: 0.9705
# Epoch 70/180
# F1 Macro Score: 0.94076
# 1000/1000 - 9s - loss: 0.0848 - accuracy: 0.9688 - val_loss: 0.0788 - val_accuracy: 0.9705
# Epoch 71/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0852 - accuracy: 0.9686 - val_loss: 0.0786 - val_accuracy: 0.9705
# Epoch 72/180
# F1 Macro Score: 0.94088
# 1000/1000 - 9s - loss: 0.0846 - accuracy: 0.9688 - val_loss: 0.0786 - val_accuracy: 0.9705
# Epoch 73/180
# F1 Macro Score: 0.94105
# 1000/1000 - 9s - loss: 0.0848 - accuracy: 0.9687 - val_loss: 0.0786 - val_accuracy: 0.9706
# Epoch 74/180
# F1 Macro Score: 0.94094
# 1000/1000 - 9s - loss: 0.0847 - accuracy: 0.9688 - val_loss: 0.0785 - val_accuracy: 0.9706
# Epoch 75/180
# F1 Macro Score: 0.94095
# 1000/1000 - 9s - loss: 0.0847 - accuracy: 0.9687 - val_loss: 0.0788 - val_accuracy: 0.9705
# Epoch 76/180
# F1 Macro Score: 0.94021
# 1000/1000 - 9s - loss: 0.0843 - accuracy: 0.9689 - val_loss: 0.0796 - val_accuracy: 0.9703
# Epoch 77/180
# F1 Macro Score: 0.94094
# 1000/1000 - 9s - loss: 0.0845 - accuracy: 0.9688 - val_loss: 0.0787 - val_accuracy: 0.9706
# Epoch 78/180
# F1 Macro Score: 0.94095
# 1000/1000 - 10s - loss: 0.0851 - accuracy: 0.9687 - val_loss: 0.0786 - val_accuracy: 0.9706
# Epoch 79/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0843 - accuracy: 0.9688 - val_loss: 0.0786 - val_accuracy: 0.9705
# Epoch 80/180
# F1 Macro Score: 0.94096
# 1000/1000 - 9s - loss: 0.0841 - accuracy: 0.9689 - val_loss: 0.0785 - val_accuracy: 0.9706
# Epoch 81/180
# F1 Macro Score: 0.94095
# 1000/1000 - 9s - loss: 0.0847 - accuracy: 0.9688 - val_loss: 0.0784 - val_accuracy: 0.9706
# Epoch 82/180
# F1 Macro Score: 0.94103
# 1000/1000 - 9s - loss: 0.0848 - accuracy: 0.9687 - val_loss: 0.0786 - val_accuracy: 0.9706
# Epoch 83/180
# F1 Macro Score: 0.94070
# 1000/1000 - 9s - loss: 0.0840 - accuracy: 0.9689 - val_loss: 0.0786 - val_accuracy: 0.9705
# Epoch 84/180
# F1 Macro Score: 0.94060
# 1000/1000 - 9s - loss: 0.0839 - accuracy: 0.9689 - val_loss: 0.0788 - val_accuracy: 0.9705
# Epoch 85/180
# F1 Macro Score: 0.94075
# 1000/1000 - 9s - loss: 0.0838 - accuracy: 0.9690 - val_loss: 0.0785 - val_accuracy: 0.9705
# Epoch 86/180
# F1 Macro Score: 0.94077
# 1000/1000 - 9s - loss: 0.0838 - accuracy: 0.9690 - val_loss: 0.0785 - val_accuracy: 0.9705
# Epoch 87/180
# F1 Macro Score: 0.94117
# 1000/1000 - 10s - loss: 0.0837 - accuracy: 0.9690 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 88/180
# F1 Macro Score: 0.94078
# 1000/1000 - 9s - loss: 0.0838 - accuracy: 0.9690 - val_loss: 0.0786 - val_accuracy: 0.9705
# Epoch 89/180
# F1 Macro Score: 0.94076
# 1000/1000 - 9s - loss: 0.0835 - accuracy: 0.9690 - val_loss: 0.0785 - val_accuracy: 0.9705
# Epoch 90/180
# F1 Macro Score: 0.94107
# 1000/1000 - 9s - loss: 0.0832 - accuracy: 0.9691 - val_loss: 0.0783 - val_accuracy: 0.9706
# Epoch 91/180
# F1 Macro Score: 0.94110
# 1000/1000 - 9s - loss: 0.0829 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 92/180
# F1 Macro Score: 0.94125
# 1000/1000 - 9s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 93/180
# F1 Macro Score: 0.94112
# 1000/1000 - 9s - loss: 0.0829 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 94/180
# F1 Macro Score: 0.94111
# 1000/1000 - 9s - loss: 0.0830 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 95/180
# F1 Macro Score: 0.94113
# 1000/1000 - 9s - loss: 0.0834 - accuracy: 0.9691 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 96/180
# F1 Macro Score: 0.94120
# 1000/1000 - 10s - loss: 0.0827 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 97/180
# F1 Macro Score: 0.94117
# 1000/1000 - 9s - loss: 0.0832 - accuracy: 0.9691 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 98/180
# F1 Macro Score: 0.94115
# 1000/1000 - 10s - loss: 0.0831 - accuracy: 0.9691 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 99/180
# F1 Macro Score: 0.94118
# 1000/1000 - 9s - loss: 0.0826 - accuracy: 0.9692 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 100/180
# F1 Macro Score: 0.94113
# 1000/1000 - 9s - loss: 0.0825 - accuracy: 0.9692 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 101/180
# F1 Macro Score: 0.94114
# 1000/1000 - 9s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 102/180
# F1 Macro Score: 0.94117
# 1000/1000 - 10s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 103/180
# F1 Macro Score: 0.94120
# 1000/1000 - 9s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 104/180
# F1 Macro Score: 0.94118
# 1000/1000 - 9s - loss: 0.0828 - accuracy: 0.9691 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 105/180
# F1 Macro Score: 0.94116
# 1000/1000 - 10s - loss: 0.0829 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 106/180
# F1 Macro Score: 0.94114
# 1000/1000 - 9s - loss: 0.0830 - accuracy: 0.9692 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch
- loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 172/180
# F1 Macro Score: 0.94106
# 1000/1000 - 9s - loss: 0.0820 - accuracy: 0.9694 - val_loss: 0.0781 - val_accuracy: 0.9705
# Epoch 173/180
# F1 Macro Score: 0.94110
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 174/180
# F1 Macro Score: 0.94098
# 1000/1000 - 10s - loss: 0.0820 - accuracy: 0.9694 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 175/180
# F1 Macro Score: 0.94110
# 1000/1000 - 9s - loss: 0.0821 - accuracy: 0.9694 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 176/180
# F1 Macro Score: 0.94113
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 177/180
# F1 Macro Score: 0.94110
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 178/180
# F1 Macro Score: 0.94118
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0781 - val_accuracy: 0.9706
# Epoch 179/180
# F1 Macro Score: 0.94113
# 1000/1000 - 9s - loss: 0.0824 - accuracy: 0.9693 - val_loss: 0.0782 - val_accuracy: 0.9706
# Epoch 180/180
# F1 Macro Score: 0.94106
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9693 - val_loss: 0.0781 - val_accuracy: 0.9706
# Training fold 2 completed. macro f1 score : 0.94106
# Our training dataset shape is (1000, 4000, 30)
# Our validation dataset shape is (250, 4000, 30)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.84806
# 1000/1000 - 35s - loss: 0.5857 - accuracy: 0.8468 - val_loss: 0.8671 - val_accuracy: 0.9230
# Epoch 2/180
# F1 Macro Score: 0.90686
# 1000/1000 - 9s - loss: 0.2083 - accuracy: 0.9552 - val_loss: 0.4808 - val_accuracy: 0.9558
# Epoch 3/180
# F1 Macro Score: 0.93077
# 1000/1000 - 9s - loss: 0.1535 - accuracy: 0.9632 - val_loss: 0.2233 - val_accuracy: 0.9654
# Epoch 4/180
# F1 Macro Score: 0.93409
# 1000/1000 - 9s - loss: 0.1375 - accuracy: 0.9646 - val_loss: 0.1485 - val_accuracy: 0.9666
# Epoch 5/180
# F1 Macro Score: 0.93505
# ...
# Epoch 58/180
# F1 Macro Score: 0.94011
# 1000/1000 - 9s - loss: 0.0841 - accuracy: 0.9691 - val_loss: 0.0826 - val_accuracy: 0.9688
# Epoch 59/180
# F1 Macro Score: 0.93981
# 1000/1000 - 10s - loss: 0.0848 - accuracy: 0.9690 - val_loss: 0.0822 - val_accuracy: 0.9690
# Epoch 60/180
# F1 Macro Score: 0.93989
# 1000/1000 - 9s - loss: 0.0849 - accuracy: 0.9690 - val_loss: 0.0829 - val_accuracy: 0.9688
# Epoch 61/180
# F1 Macro Score: 0.94034
# 1000/1000 - 9s - loss: 0.0843 - accuracy: 0.9691 - val_loss: 0.0823 - val_accuracy: 0.9689
# Epoch 62/180
# F1 Macro Score: 0.94034
# 1000/1000 - 9s - loss: 0.0842 - accuracy: 0.9691 - val_loss: 0.0818 - val_accuracy: 0.9691
# Epoch 63/180
# F1 Macro Score: 0.94020
# 1000/1000 - 9s - loss: 0.0837 - accuracy: 0.9692 - val_loss: 0.0821 - val_accuracy: 0.9690
# Epoch 64/180
# F1 Macro Score: 0.94040
# 1000/1000 - 9s - loss: 0.0842 - accuracy: 0.9691 - val_loss: 0.0819 - val_accuracy: 0.9691
# Epoch 65/180
# F1 Macro Score: 0.94017
# 1000/1000 - 9s - loss: 0.0836 - accuracy: 0.9693 - val_loss: 0.0819 - val_accuracy: 0.9690
# Epoch 66/180
# F1 Macro Score: 0.94029
# 1000/1000 - 9s - loss: 0.0835 - accuracy: 0.9693 - val_loss: 0.0818 - val_accuracy: 0.9690
# Epoch 67/180
# F1 Macro Score: 0.94030
# 1000/1000 - 9s - loss: 0.0838 - accuracy: 0.9692 - val_loss: 0.0820 - val_accuracy: 0.9690
# Epoch 68/180
# F1 Macro Score: 0.94041
# 1000/1000 - 10s - loss: 0.0832 - accuracy: 0.9694 - val_loss: 0.0816 - val_accuracy: 0.9691
# Epoch 69/180
# F1 Macro Score: 0.94039
# 1000/1000 - 9s - loss: 0.0836 - accuracy: 0.9693 - val_loss: 0.0815 - val_accuracy: 0.9691
# Epoch 70/180
# F1 Macro Score: 0.94037
# 1000/1000 - 9s - loss: 0.0834 - accuracy: 0.9693 - val_loss: 0.0818 - val_accuracy: 0.9690
# Epoch 71/180
# F1 Macro Score: 0.94033
# 1000/1000 - 9s - loss: 0.0836 - accuracy: 0.9693 - val_loss: 0.0815 - val_accuracy: 0.9692
# Epoch 72/180
# F1 Macro Score: 0.94058
# 1000/1000 - 9s - loss: 0.0829 - accuracy: 0.9695 - val_loss: 0.0814 - val_accuracy: 0.9692
# Epoch 73/180
# F1 Macro Score: 0.93984
# 1000/1000 - 9s - loss: 0.0829 - accuracy: 0.9695 - val_loss: 0.0814 - val_accuracy: 0.9691
# Epoch 74/180
# F1 Macro Score: 0.94035
# 1000/1000 - 9s - loss: 0.0831 - accuracy: 0.9694 - val_loss: 0.0817 - val_accuracy: 0.9689
# Epoch 75/180
# F1 Macro Score: 0.94041
# 1000/1000 - 9s - loss: 0.0829 - accuracy: 0.9694 - val_loss: 0.0814 - val_accuracy: 0.9691
# Epoch 76/180
# F1 Macro Score: 0.94065
# 1000/1000 - 10s - loss: 0.0826 - accuracy: 0.9695 - val_loss: 0.0815 - val_accuracy: 0.9692
# Epoch 77/180
# F1 Macro Score: 0.94042
# 1000/1000 - 10s - loss: 0.0826 - accuracy: 0.9695 - val_loss: 0.0814 - val_accuracy: 0.9691
# Epoch 78/180
# F1 Macro Score: 0.94013
# 1000/1000 - 10s - loss: 0.0834 - accuracy: 0.9694 - val_loss: 0.0819 - val_accuracy: 0.9691
# Epoch 79/180
# F1 Macro Score: 0.94047
# 1000/1000 - 9s - loss: 0.0825 - accuracy: 0.9695 - val_loss: 0.0813 - val_accuracy: 0.9692
# Epoch 80/180
# F1 Macro Score: 0.94063
# 1000/1000 - 9s - loss: 0.0823 - accuracy: 0.9696 - val_loss: 0.0814 - val_accuracy: 0.9692
# Epoch 81/180
# F1 Macro Score: 0.94047
# 1000/1000 - 9s - loss: 0.0827 - accuracy: 0.9696 - val_loss: 0.0814 - val_accuracy: 0.9691
# Epoch 82/180
# F1 Macro Score: 0.94033
# 1000/1000 - 9s - loss: 0.0826 - accuracy: 0.9695 - val_loss: 0.0817 - val_accuracy: 0.9689
# Epoch 83/180
# F1 Macro Score: 0.94034
# 1000/1000 - 9s - loss: 0.0820 - accuracy: 0.9697 - val_loss: 0.0814 - val_accuracy: 0.9690
# Epoch 84/180
# F1 Macro Score: 0.94049
# 1000/1000 - 9s - loss: 0.0819 - accuracy: 0.9697 - val_loss: 0.0813 - val_accuracy: 0.9692
# Epoch 85/180
# F1 Macro Score: 0.93988
# 1000/1000 - 9s - loss: 0.0820 - accuracy: 0.9697 - val_loss: 0.0820 - val_accuracy: 0.9689
# Epoch 86/180
# F1 Macro Score: 0.94060
# 1000/1000 - 9s - loss: 0.0820 - accuracy: 0.9697 - val_loss: 0.0811 - val_accuracy: 0.9693
# Epoch 87/180
# F1 Macro Score: 0.94015
# 1000/1000 - 9s - loss: 0.0818 - accuracy: 0.9698 - val_loss: 0.0811 - val_accuracy: 0.9691
# Epoch 88/180
# F1 Macro Score: 0.94028
# 1000/1000 - 9s - loss: 0.0818 - accuracy: 0.9697 - val_loss: 0.0811 - val_accuracy: 0.9691
# Epoch 89/180
# F1 Macro Score: 0.94017
# 1000/1000 - 9s - loss: 0.0814 - accuracy: 0.9698 - val_loss: 0.0813 - val_accuracy: 0.9691
# Epoch 90/180
# F1 Macro Score: 0.94051
# 1000/1000 - 9s - loss: 0.0813 - accuracy: 0.9698 - val_loss: 0.0812 - val_accuracy: 0.9691
# Epoch 91/180
# F1 Macro Score: 0.94084
# 1000/1000 - 9s - loss: 0.0812 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9694
# Epoch 92/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9698 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 93/180
# F1 Macro Score: 0.94073
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 94/180
# F1 Macro Score: 0.94096
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9694
# Epoch 95/180
# F1 Macro Score: 0.94088
# 1000/1000 - 10s - loss: 0.0813 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 96/180
# F1 Macro Score: 0.94074
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 97/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 98/180
# F1 Macro Score: 0.94088
# 1000/1000 - 9s - loss: 0.0812 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 99/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 100/180
# F1 Macro Score: 0.94085
# 1000/1000 - 10s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 101/180
# F1 Macro Score: 0.94083
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 102/180
# F1 Macro Score: 0.94071
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 103/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 104/180
# F1 Macro Score: 0.94074
# 1000/1000 - 10s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 105/180
# F1 Macro Score: 0.94069
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 106/180
# F1 Macro Score: 0.94086
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 107/180
# F1 Macro Score: 0.94075
# 1000/1000 - 10s - loss: 0.0809 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 108/180
# F1 Macro Score: 0.94061
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 109/180
# F1 Macro Score: 0.94073
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 110/180
# F1 Macro Score: 0.94080
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 111/180
# F1 Macro Score: 0.94079
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 112/180
# F1 Macro Score: 0.94087
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 113/180
# F1 Macro Score: 0.94046
# 1000/1000 - 9s - loss: 0.0819 - accuracy: 0.9697 - val_loss: 0.0809 - val_accuracy: 0.9692
# Epoch 114/180
# F1 Macro Score: 0.94062
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 115/180
# F1 Macro Score: 0.94064
# 1000/1000 - 9s - loss: 0.0813 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 116/180
# F1 Macro Score: 0.94090
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 117/180
# F1 Macro Score: 0.94075
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 118/180
# F1 Macro Score: 0.94090
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9694
# Epoch 119/180
# F1 Macro Score: 0.94077
# 1000/1000 - 9s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 120/180
# F1 Macro Score: 0.94074
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 121/180
# F1 Macro Score: 0.94070
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 122/180
# F1 Macro Score: 0.94088
# 1000/1000 - 10s - loss: 0.0813 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 123/180
# F1 Macro Score: 0.94076
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 124/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 125/180
# F1 Macro Score: 0.94080
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 126/180
# F1 Macro Score: 0.94087
# 1000/1000 - 9s - loss: 0.0813 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 127/180
# F1 Macro Score: 0.94079
# 1000/1000 - 9s - loss: 0.0820 - accuracy: 0.9697 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 128/180
# F1 Macro Score: 0.94043
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 129/180
# F1 Macro Score: 0.94060
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 130/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 131/180
# F1 Macro Score: 0.94093
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 132/180
# F1 Macro Score: 0.94088
# 1000/1000 - 10s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 133/180
# F1 Macro Score: 0.94072
# 1000/1000 - 10s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 134/180
# F1 Macro Score: 0.94058
# 1000/1000 - 9s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 135/180
# F1 Macro Score: 0.94056
# 1000/1000 - 10s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 136/180
# F1 Macro Score: 0.94078
# 1000/1000 - 9s - loss: 0.0812 - accuracy: 0.9700 - val_loss: 0.0810 - val_accuracy: 0.9693
# Epoch 137/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 138/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0803 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 139/180
# F1 Macro Score: 0.94070
# 1000/1000 - 9s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 140/180
# F1 Macro Score: 0.94051
# 1000/1000 - 10s - loss: 0.0812 - accuracy: 0.9698 - val_loss: 0.0808 - val_accuracy: 0.9692
# Epoch 141/180
# F1 Macro Score: 0.94064
# 1000/1000 - 10s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 142/180
# F1 Macro Score: 0.94070
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 143/180
# F1 Macro Score: 0.94074
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 144/180
# F1 Macro Score: 0.94055
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 145/180
# F1 Macro Score: 0.94081
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 146/180
# F1 Macro Score: 0.94075
# 1000/1000 - 9s - loss: 0.0809 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 147/180
# F1 Macro Score: 0.94086
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 148/180
# F1 Macro Score: 0.94043
# 1000/1000 - 9s - loss: 0.0810 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9692
# Epoch 149/180
# F1 Macro Score: 0.94075
# 1000/1000 - 10s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 150/180
# F1 Macro Score: 0.94076
# 1000/1000 - 9s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 151/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0803 - accuracy: 0.9700 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 152/180
# F1 Macro Score: 0.94078
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 153/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 154/180
# F1 Macro Score: 0.94082
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9694
# Epoch 155/180
# F1 Macro Score: 0.94078
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 156/180
# F1 Macro Score: 0.94081
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 157/180
# F1 Macro Score: 0.94070
# 1000/1000 - 9s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 158/180
# F1 Macro Score: 0.94068
# 1000/1000 - 10s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 159/180
# F1 Macro Score: 0.94079
# 1000/1000 - 9s - loss: 0.0805 - accuracy: 0.9701 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 160/180
# F1 Macro Score: 0.94087
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 161/180
# F1 Macro Score: 0.94061
# 1000/1000 - 9s - loss: 0.0801 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 162/180
# F1 Macro Score: 0.94065
# 1000/1000 - 9s - loss: 0.0803 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 163/180
# F1 Macro Score: 0.94061
# 1000/1000 - 9s - loss: 0.0811 - accuracy: 0.9699 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 164/180
# F1 Macro Score: 0.94078
# 1000/1000 - 10s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 165/180
# F1 Macro Score: 0.94063
# 1000/1000 - 10s - loss: 0.0803 - accuracy: 0.9701 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 166/180
# F1 Macro Score: 0.94051
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 167/180
# F1 Macro Score: 0.94088
# 1000/1000 - 10s - loss: 0.0805 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 168/180
# F1 Macro Score: 0.94069
# 1000/1000 - 9s - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 169/180
# F1 Macro Score: 0.94051
# 1000/1000 - 9s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 170/180
# F1 Macro Score: 0.94048
# 1000/1000 - 9s - loss: 0.0803 - accuracy: 0.9701 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 171/180
# F1 Macro Score: 0.94065
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 172/180
# F1 Macro Score: 0.94060
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9701 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 173/180
# F1 Macro Score: 0.94085
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9702 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 174/180
# F1 Macro Score: 0.94073
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 175/180
# F1 Macro Score: 0.94074
# 1000/1000 - 9s - loss: 0.0803 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 176/180
# F1 Macro Score: 0.94064
# 1000/1000 - 10s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 177/180
# F1 Macro Score: 0.94091
# 1000/1000 - 9s - loss: 0.0804 - accuracy: 0.9701 - val_loss: 0.0808 - val_accuracy: 0.9694
# Epoch 178/180
# F1 Macro Score: 0.94072
# 1000/1000 - 9s - loss: 0.0802 - accuracy: 0.9701 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 179/180
# F1 Macro Score: 0.94045
# 1000/1000 - 9s - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.0808 - val_accuracy: 0.9693
# Epoch 180/180
# F1 Macro Score: 0.94080
# 1000/1000 - 9s - loss: 0.0806 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9693
# Training fold 5 completed. macro f1 score : 0.94080
# Training completed. oof macro f1 score : 0.94055
# Training completed...

# %%
# !kaggle competitions submit -c liverpool-ion-switching -f submission_wavenet.csv -m "crg proba knn"
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/jupyter/.kaggle/kaggle.json'
# 100%|██████████████████████████████████████| 21.0M/21.0M [00:03<00:00, 6.09MB/s]
# Successfully submitted to University of Liverpool - Ion Switching

# %%
3
# Out:
# 3
