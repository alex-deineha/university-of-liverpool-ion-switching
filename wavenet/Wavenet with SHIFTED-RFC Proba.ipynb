# %% [markdown]
# # Thanks to https://www.kaggle.com/siavrez/wavenet-keras, learned a lot.

# %%
# !pip install tensorflow_addons
import tensorflow as tf
from tensorflow.keras.layers import *
import pandas as pd
import numpy as np
import random
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
import tensorflow_addons as tfa
import gc

from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Requirement already satisfied: tensorflow_addons in /opt/conda/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied: typeguard>=2.7 in /opt/conda/lib/python3.7/site-packages (from tensorflow_addons) (2.7.1)

# %%
# configurations and main hyperparammeters
EPOCHS = 110
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 321 
LR = 0.001
SPLITS = 5

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %%
# read data
def read_data():
    train = pd.read_csv('../input/data-without-drift/train_clean.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv('../input/data-without-drift/test_clean.csv', dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv('../input/liverpool-ion-switching/sample_submission.csv', dtype={'time': np.float32})
    
    Y_train_proba = np.load("../input/ion-shifted-rfc-proba/Y_train_proba.npy")
    Y_test_proba = np.load("../input/ion-shifted-rfc-proba/Y_test_proba.npy")
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]

    return train, test, sub

# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    train_input_mean = train.signal.mean()
    train_input_sigma = train.signal.std()
    train['signal'] = (train.signal - train_input_mean) / train_input_sigma
    test['signal'] = (test.signal - train_input_mean) / train_input_sigma
    return train, test

# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)
    # create leads and lags (1, 2, 3 making them 6 features)
    df = lag_with_pct_change(df, [1, 2, 3])
    # create signal ** 2 (this is the new feature)
    df['signal_2'] = df['signal'] ** 2
    return df

# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# %%
def Classifier(shape_):
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters = filters,
                   kernel_size = 1,
                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = Multiply()([tanh_out, sigm_out])
            x = Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = Add()([res_x, x])
        return res_x
    
    def cbr(x, out_layer, kernel, stride, dilation):
        x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        return x
    
    
    def res_rnn_block(x, hidden_units=64, num_layers=2):

        x = Conv1D(filters=hidden_units*2, kernel_size = 1, padding = 'same')(x)
        res_x = x
        for _ in range(num_layers):
            x = Bidirectional(GRU(units=hidden_units, return_sequences=True))(x)
            res_x = Add()([res_x, x])
        return res_x        
    
    inp = Input(shape = (shape_))
    x = cbr(inp, 64, 7, 1, 1)
    x = BatchNormalization()(x)
    x = wave_block(x, 16, 3, 12)
    x = BatchNormalization()(x)
    x = wave_block(x, 32, 3, 8)
    x = BatchNormalization()(x)
    x = wave_block(x, 64, 3, 4)
    x = BatchNormalization()(x)
    x = wave_block(x, 128, 3, 1)
    x = cbr(x, 32, 7, 1, 1)
    x = BatchNormalization()(x)
    
    x = res_rnn_block(x, hidden_units=32, num_layers=2)
    x = BatchNormalization()(x)
    
    x = Dropout(0.2)(x)    
    out = Dense(11, activation = 'softmax', name = 'out')(x)
    
    model = models.Model(inputs = inp, outputs = out)
    
    opt = Adam(lr = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    return model

# %%
Classifier((None, 19)).summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, None, 19)]   0
# __________________________________________________________________________________________________
# conv1d_326 (Conv1D)             (None, None, 64)     8576        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, 64)     256         conv1d_326[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, 64)     256         activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_327 (Conv1D)             (None, None, 16)     1040        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv1d_328 (Conv1D)             (None, None, 16)     784         conv1d_327[0][0]
# __________________________________________________________________________________________________
# conv1d_329 (Conv1D)             (None, None, 16)     784         conv1d_327[0][0]
# __________________________________________________________________________________________________
# multiply_100 (Multiply)         (None, None, 16)     0           conv1d_328[0][0]
#                                                                  conv1d_329[0][0]
# __________________________________________________________________________________________________
# conv1d_330 (Conv1D)             (None, None, 16)     272         multiply_100[0][0]
# __________________________________________________________________________________________________
# conv1d_331 (Conv1D)             (None, None, 16)     784         conv1d_330[0][0]
# __________________________________________________________________________________________________
# conv1d_332 (Conv1D)             (None, None, 16)     784         conv1d_330[0][0]
# __________________________________________________________________________________________________
# multiply_101 (Multiply)         (None, None, 16)     0           conv1d_331[0][0]
#                                                                  conv1d_332[0][0]
# __________________________________________________________________________________________________
# conv1d_333 (Conv1D)             (None, None, 16)     272         multiply_101[0][0]
# __________________________________________________________________________________________________
# conv1d_334 (Conv1D)             (None, None, 16)     784         conv1d_333[0][0]
# __________________________________________________________________________________________________
# conv1d_335 (Conv1D)             (None, None, 16)     784         conv1d_333[0][0]
# __________________________________________________________________________________________________
# multiply_102 (Multiply)         (None, None, 16)     0           conv1d_334[0][0]
#                                                                  conv1d_335[0][0]
# __________________________________________________________________________________________________
# conv1d_336 (Conv1D)             (None, None, 16)     272         multiply_102[0][0]
# __________________________________________________________________________________________________
# conv1d_337 (Conv1D)             (None, None, 16)     784         conv1d_336[0][0]
# __________________________________________________________________________________________________
# conv1d_338 (Conv1D)             (None, None, 16)     784         conv1d_336[0][0]
# __________________________________________________________________________________________________
# multiply_103 (Multiply)         (None, None, 16)     0           conv1d_337[0][0]
#                                                                  conv1d_338[0][0]
# __________________________________________________________________________________________________
# conv1d_339 (Conv1D)             (None, None, 16)     272         multiply_103[0][0]
# __________________________________________________________________________________________________
# conv1d_340 (Conv1D)             (None, None, 16)     784         conv1d_339[0][0]
# __________________________________________________________________________________________________
# conv1d_341 (Conv1D)             (None, None, 16)     784         conv1d_339[0][0]
# __________________________________________________________________________________________________
# multiply_104 (Multiply)         (None, None, 16)     0           conv1d_340[0][0]
#                                                                  conv1d_341[0][0]
# __________________________________________________________________________________________________
# conv1d_342 (Conv1D)             (None, None, 16)     272         multiply_104[0][0]
# __________________________________________________________________________________________________
# conv1d_343 (Conv1D)             (None, None, 16)     784         conv1d_342[0][0]
# __________________________________________________________________________________________________
# conv1d_344 (Conv1D)             (None, None, 16)     784         conv1d_342[0][0]
# __________________________________________________________________________________________________
# multiply_105 (Multiply)         (None, None, 16)     0           conv1d_343[0][0]
#                                                                  conv1d_344[0][0]
# __________________________________________________________________________________________________
# conv1d_345 (Conv1D)             (None, None, 16)     272         multiply_105[0][0]
# __________________________________________________________________________________________________
# conv1d_346 (Conv1D)             (None, None, 16)     784         conv1d_345[0][0]
# __________________________________________________________________________________________________
# conv1d_347 (Conv1D)             (None, None, 16)     784         conv1d_345[0][0]
# __________________________________________________________________________________________________
# multiply_106 (Multiply)         (None, None, 16)     0           conv1d_346[0][0]
#                                                                  conv1d_347[0][0]
# __________________________________________________________________________________________________
# conv1d_348 (Conv1D)             (None, None, 16)     272         multiply_106[0][0]
# __________________________________________________________________________________________________
# conv1d_349 (Conv1D)             (None, None, 16)     784         conv1d_348[0][0]
# __________________________________________________________________________________________________
# conv1d_350 (Conv1D)             (None, None, 16)     784         conv1d_348[0][0]
# __________________________________________________________________________________________________
# multiply_107 (Multiply)         (None, None, 16)     0           conv1d_349[0][0]
#                                                                  conv1d_350[0][0]
# __________________________________________________________________________________________________
# conv1d_351 (Conv1D)             (None, None, 16)     272         multiply_107[0][0]
# __________________________________________________________________________________________________
# conv1d_352 (Conv1D)             (None, None, 16)     784         conv1d_351[0][0]
# __________________________________________________________________________________________________
# conv1d_353 (Conv1D)             (None, None, 16)     784         conv1d_351[0][0]
# __________________________________________________________________________________________________
# add_104 (Add)                   (None, None, 16)     0           conv1d_327[0][0]
#                                                                  conv1d_330[0][0]
# __________________________________________________________________________________________________
# multiply_108 (Multiply)         (None, None, 16)     0           conv1d_352[0][0]
#                                                                  conv1d_353[0][0]
# __________________________________________________________________________________________________
# add_105 (Add)                   (None, None, 16)     0           add_104[0][0]
#                                                                  conv1d_333[0][0]
# __________________________________________________________________________________________________
# conv1d_354 (Conv1D)             (None, None, 16)     272         multiply_108[0][0]
# __________________________________________________________________________________________________
# add_106 (Add)                   (None, None, 16)     0           add_105[0][0]
#                                                                  conv1d_336[0][0]
# __________________________________________________________________________________________________
# conv1d_355 (Conv1D)             (None, None, 16)     784         conv1d_354[0][0]
# __________________________________________________________________________________________________
# conv1d_356 (Conv1D)             (None, None, 16)     784         conv1d_354[0][0]
# __________________________________________________________________________________________________
# add_107 (Add)                   (None, None, 16)     0           add_106[0][0]
#                                                                  conv1d_339[0][0]
# __________________________________________________________________________________________________
# multiply_109 (Multiply)         (None, None, 16)     0           conv1d_355[0][0]
#                                                                  conv1d_356[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, None, 16)     0           add_107[0][0]
#                                                                  conv1d_342[0][0]
# __________________________________________________________________________________________________
# conv1d_357 (Conv1D)             (None, None, 16)     272         multiply_109[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, None, 16)     0           add_108[0][0]
#                                                                  conv1d_345[0][0]
# __________________________________________________________________________________________________
# conv1d_358 (Conv1D)             (None, None, 16)     784         conv1d_357[0][0]
# __________________________________________________________________________________________________
# conv1d_359 (Conv1D)             (None, None, 16)     784         conv1d_357[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, None, 16)     0           add_109[0][0]
#                                                                  conv1d_348[0][0]
# __________________________________________________________________________________________________
# multiply_110 (Multiply)         (None, None, 16)     0           conv1d_358[0][0]
#                                                                  conv1d_359[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, None, 16)     0           add_110[0][0]
#                                                                  conv1d_351[0][0]
# __________________________________________________________________________________________________
# conv1d_360 (Conv1D)             (None, None, 16)     272         multiply_110[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, None, 16)     0           add_111[0][0]
#                                                                  conv1d_354[0][0]
# __________________________________________________________________________________________________
# conv1d_361 (Conv1D)             (None, None, 16)     784         conv1d_360[0][0]
# __________________________________________________________________________________________________
# conv1d_362 (Conv1D)             (None, None, 16)     784         conv1d_360[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, None, 16)     0           add_112[0][0]
#                                                                  conv1d_357[0][0]
# __________________________________________________________________________________________________
# multiply_111 (Multiply)         (None, None, 16)     0           conv1d_361[0][0]
#                                                                  conv1d_362[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, None, 16)     0           add_113[0][0]
#                                                                  conv1d_360[0][0]
# __________________________________________________________________________________________________
# conv1d_363 (Conv1D)             (None, None, 16)     272         multiply_111[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, None, 16)     0           add_114[0][0]
#                                                                  conv1d_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, 16)     64          add_115[0][0]
# __________________________________________________________________________________________________
# conv1d_364 (Conv1D)             (None, None, 32)     544         batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv1d_365 (Conv1D)             (None, None, 32)     3104        conv1d_364[0][0]
# __________________________________________________________________________________________________
# conv1d_366 (Conv1D)             (None, None, 32)     3104        conv1d_364[0][0]
# __________________________________________________________________________________________________
# multiply_112 (Multiply)         (None, None, 32)     0           conv1d_365[0][0]
#                                                                  conv1d_366[0][0]
# __________________________________________________________________________________________________
# conv1d_367 (Conv1D)             (None, None, 32)     1056        multiply_112[0][0]
# __________________________________________________________________________________________________
# conv1d_368 (Conv1D)             (None, None, 32)     3104        conv1d_367[0][0]
# __________________________________________________________________________________________________
# conv1d_369 (Conv1D)             (None, None, 32)     3104        conv1d_367[0][0]
# __________________________________________________________________________________________________
# multiply_113 (Multiply)         (None, None, 32)     0           conv1d_368[0][0]
#                                                                  conv1d_369[0][0]
# __________________________________________________________________________________________________
# conv1d_370 (Conv1D)             (None, None, 32)     1056        multiply_113[0][0]
# __________________________________________________________________________________________________
# conv1d_371 (Conv1D)             (None, None, 32)     3104        conv1d_370[0][0]
# __________________________________________________________________________________________________
# conv1d_372 (Conv1D)             (None, None, 32)     3104        conv1d_370[0][0]
# __________________________________________________________________________________________________
# multiply_114 (Multiply)         (None, None, 32)     0           conv1d_371[0][0]
#                                                                  conv1d_372[0][0]
# __________________________________________________________________________________________________
# conv1d_373 (Conv1D)             (None, None, 32)     1056        multiply_114[0][0]
# __________________________________________________________________________________________________
# conv1d_374 (Conv1D)             (None, None, 32)     3104        conv1d_373[0][0]
# __________________________________________________________________________________________________
# conv1d_375 (Conv1D)             (None, None, 32)     3104        conv1d_373[0][0]
# __________________________________________________________________________________________________
# multiply_115 (Multiply)         (None, None, 32)     0           conv1d_374[0][0]
#                                                                  conv1d_375[0][0]
# __________________________________________________________________________________________________
# conv1d_376 (Conv1D)             (None, None, 32)     1056        multiply_115[0][0]
# __________________________________________________________________________________________________
# conv1d_377 (Conv1D)             (None, None, 32)     3104        conv1d_376[0][0]
# __________________________________________________________________________________________________
# conv1d_378 (Conv1D)             (None, None, 32)     3104        conv1d_376[0][0]
# __________________________________________________________________________________________________
# multiply_116 (Multiply)         (None, None, 32)     0           conv1d_377[0][0]
#                                                                  conv1d_378[0][0]
# __________________________________________________________________________________________________
# conv1d_379 (Conv1D)             (None, None, 32)     1056        multiply_116[0][0]
# __________________________________________________________________________________________________
# conv1d_380 (Conv1D)             (None, None, 32)     3104        conv1d_379[0][0]
# __________________________________________________________________________________________________
# conv1d_381 (Conv1D)             (None, None, 32)     3104        conv1d_379[0][0]
# __________________________________________________________________________________________________
# multiply_117 (Multiply)         (None, None, 32)     0           conv1d_380[0][0]
#                                                                  conv1d_381[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, None, 32)     0           conv1d_364[0][0]
#                                                                  conv1d_367[0][0]
# __________________________________________________________________________________________________
# conv1d_382 (Conv1D)             (None, None, 32)     1056        multiply_117[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, None, 32)     0           add_116[0][0]
#                                                                  conv1d_370[0][0]
# __________________________________________________________________________________________________
# conv1d_383 (Conv1D)             (None, None, 32)     3104        conv1d_382[0][0]
# __________________________________________________________________________________________________
# conv1d_384 (Conv1D)             (None, None, 32)     3104        conv1d_382[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, None, 32)     0           add_117[0][0]
#                                                                  conv1d_373[0][0]
# __________________________________________________________________________________________________
# multiply_118 (Multiply)         (None, None, 32)     0           conv1d_383[0][0]
#                                                                  conv1d_384[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, None, 32)     0           add_118[0][0]
#                                                                  conv1d_376[0][0]
# __________________________________________________________________________________________________
# conv1d_385 (Conv1D)             (None, None, 32)     1056        multiply_118[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, None, 32)     0           add_119[0][0]
#                                                                  conv1d_379[0][0]
# __________________________________________________________________________________________________
# conv1d_386 (Conv1D)             (None, None, 32)     3104        conv1d_385[0][0]
# __________________________________________________________________________________________________
# conv1d_387 (Conv1D)             (None, None, 32)     3104        conv1d_385[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, None, 32)     0           add_120[0][0]
#                                                                  conv1d_382[0][0]
# __________________________________________________________________________________________________
# multiply_119 (Multiply)         (None, None, 32)     0           conv1d_386[0][0]
#                                                                  conv1d_387[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, None, 32)     0           add_121[0][0]
#                                                                  conv1d_385[0][0]
# __________________________________________________________________________________________________
# conv1d_388 (Conv1D)             (None, None, 32)     1056        multiply_119[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, None, 32)     0           add_122[0][0]
#                                                                  conv1d_388[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, 32)     128         add_123[0][0]
# __________________________________________________________________________________________________
# conv1d_389 (Conv1D)             (None, None, 64)     2112        batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv1d_390 (Conv1D)             (None, None, 64)     12352       conv1d_389[0][0]
# __________________________________________________________________________________________________
# conv1d_391 (Conv1D)             (None, None, 64)     12352       conv1d_389[0][0]
# __________________________________________________________________________________________________
# multiply_120 (Multiply)         (None, None, 64)     0           conv1d_390[0][0]
#                                                                  conv1d_391[0][0]
# __________________________________________________________________________________________________
# conv1d_392 (Conv1D)             (None, None, 64)     4160        multiply_120[0][0]
# __________________________________________________________________________________________________
# conv1d_393 (Conv1D)             (None, None, 64)     12352       conv1d_392[0][0]
# __________________________________________________________________________________________________
# conv1d_394 (Conv1D)             (None, None, 64)     12352       conv1d_392[0][0]
# __________________________________________________________________________________________________
# multiply_121 (Multiply)         (None, None, 64)     0           conv1d_393[0][0]
#                                                                  conv1d_394[0][0]
# __________________________________________________________________________________________________
# conv1d_395 (Conv1D)             (None, None, 64)     4160        multiply_121[0][0]
# __________________________________________________________________________________________________
# conv1d_396 (Conv1D)             (None, None, 64)     12352       conv1d_395[0][0]
# __________________________________________________________________________________________________
# conv1d_397 (Conv1D)             (None, None, 64)     12352       conv1d_395[0][0]
# __________________________________________________________________________________________________
# multiply_122 (Multiply)         (None, None, 64)     0           conv1d_396[0][0]
#                                                                  conv1d_397[0][0]
# __________________________________________________________________________________________________
# conv1d_398 (Conv1D)             (None, None, 64)     4160        multiply_122[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, None, 64)     0           conv1d_389[0][0]
#                                                                  conv1d_392[0][0]
# __________________________________________________________________________________________________
# conv1d_399 (Conv1D)             (None, None, 64)     12352       conv1d_398[0][0]
# __________________________________________________________________________________________________
# conv1d_400 (Conv1D)             (None, None, 64)     12352       conv1d_398[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, None, 64)     0           add_124[0][0]
#                                                                  conv1d_395[0][0]
# __________________________________________________________________________________________________
# multiply_123 (Multiply)         (None, None, 64)     0           conv1d_399[0][0]
#                                                                  conv1d_400[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, None, 64)     0           add_125[0][0]
#                                                                  conv1d_398[0][0]
# __________________________________________________________________________________________________
# conv1d_401 (Conv1D)             (None, None, 64)     4160        multiply_123[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, None, 64)     0           add_126[0][0]
#                                                                  conv1d_401[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, 64)     256         add_127[0][0]
# __________________________________________________________________________________________________
# conv1d_402 (Conv1D)             (None, None, 128)    8320        batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv1d_403 (Conv1D)             (None, None, 128)    49280       conv1d_402[0][0]
# __________________________________________________________________________________________________
# conv1d_404 (Conv1D)             (None, None, 128)    49280       conv1d_402[0][0]
# __________________________________________________________________________________________________
# multiply_124 (Multiply)         (None, None, 128)    0           conv1d_403[0][0]
#                                                                  conv1d_404[0][0]
# __________________________________________________________________________________________________
# conv1d_405 (Conv1D)             (None, None, 128)    16512       multiply_124[0][0]
# __________________________________________________________________________________________________
# add_128 (Add)                   (None, None, 128)    0           conv1d_402[0][0]
#                                                                  conv1d_405[0][0]
# __________________________________________________________________________________________________
# conv1d_406 (Conv1D)             (None, None, 32)     28704       add_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, 32)     128         conv1d_406[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, 32)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, 32)     128         activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_407 (Conv1D)             (None, None, 64)     2112        batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, None, 64)     18816       conv1d_407[0][0]
# __________________________________________________________________________________________________
# add_129 (Add)                   (None, None, 64)     0           conv1d_407[0][0]
#                                                                  bidirectional_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, None, 64)     18816       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# add_130 (Add)                   (None, None, 64)     0           add_129[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, 64)     256         add_130[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 64)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# out (Dense)                     (None, None, 11)     715         dropout_2[0][0]
# ==================================================================================================
# Total params: 401,947
# Trainable params: 401,211
# Non-trainable params: 736
# __________________________________________________________________________________________________

# %%
# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    else:
        lr = LR / 100
    return lr

# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')

# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
    config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
    tf.compat.v1.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')

        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        model = Classifier(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 1,
                  validation_data = (valid_x,valid_y))
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv('submission_wavenet.csv', index=False, float_format='%.4f')
    
# this function run our entire program
def run_everything():
    
    print('Reading Data Started...')
    train, test, sample_submission = read_data()
    train, test = normalize(train, test)
    print('Reading and Normalizing Data Completed')
        
    print('Creating Features')
    print('Feature Engineering Started...')
    train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
    test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)
    train, test, features = feature_selection(train, test)
    print('Feature Engineering Completed...')
        
   
    print(f'Training Wavenet model with {SPLITS} folds of GroupKFold Started...')
    run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
    print('Training completed...')
    
run_everything()

# %%
# !kaggle competitions submit -c liverpool-ion-switching -f submission.csv -m "Message"
